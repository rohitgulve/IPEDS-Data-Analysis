# %%
import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
IPED_data = pd.read_excel("./Data/IPEDS_data.xlsx")

# %%
IPED_data.head()
# Out:
#    ID number                                 Name  year    ZIP code  \
# 0     100654             Alabama A & M University  2013       35762
# 1     100663  University of Alabama at Birmingham  2013  35294-0110
# 2     100690                   Amridge University  2013  36117-3553
# 3     100706  University of Alabama in Huntsville  2013       35899
# 4     100724             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# ...

# %%
IPED_data.columns
# Out:
# Index(['ID number', 'Name', 'year', 'ZIP code', 'Highest degree offered',
#        'County name', 'Longitude location of institution',
#        'Latitude location of institution', 'Religious affiliation',
#        'Offers Less than one year certificate',
#        ...
#        'Percent of freshmen  receiving federal grant aid',
#        'Percent of freshmen receiving Pell grants',
#        'Percent of freshmen receiving other federal grant aid',
#        'Percent of freshmen receiving state/local grant aid',
#        'Percent of freshmen receiving institutional grant aid',
#        'Percent of freshmen receiving student loan aid',
#        'Percent of freshmen receiving federal student loans',
#        'Percent of freshmen receiving other loan aid',
#        'Endowment assets (year end) per FTE enrollment (GASB)',
#        'Endowment assets (year end) per FTE enrollment (FASB)'],
#       dtype='object', length=145)

# %%
IPED_data.shape
# Out:
# (1534, 145)

# %%
IPED_data.describe()
# Out:
#            ID number    year  Longitude location of institution  \
# count    1534.000000  1534.0                        1534.000000
# mean   189091.037810  2013.0                         -88.342338
# std     58641.915456     0.0                          14.838804
# min    100654.000000  2013.0                        -158.062444
# 25%    153148.500000  2013.0                         -94.576341
# 50%    186508.000000  2013.0                         -84.514218
# 75%    215730.000000  2013.0                         -77.207136
# max    456490.000000  2013.0                         -67.456534
#
#        Latitude location of institution  Applicants total  Admissions total  \
# count                       1534.000000       1377.000000       1377.000000
# mean                          38.729993       6391.193174       3554.880174
# std                            4.832832       8787.469171       4309.457606
# min                           19.701854          0.000000          0.000000
# ...

# %%
IPED_data.isna().sum().sort_values(ascending = False)
# Out:
# Endowment assets (year end) per FTE enrollment (GASB)      1018
# SAT Writing 25th percentile score                           820
# SAT Writing 75th percentile score                           820
# Number of first-time undergraduates - foreign countries     623
# Percent of first-time undergraduates - out-of-state         623
#                                                            ...
# Level of institution                                          0
# Control of institution                                        0
# Historically Black College or University                      0
# Tribal college                                                0
# State abbreviation                                            0
# Length: 145, dtype: int64

# %%
# Check for duplicates
print(IPED_data.duplicated().sum())
# Out:
# 0

# %%
# Step 1: Calculate the percentage of missing values in each column
percent_missing = IPED_data.isna().sum() / len(IPED_data) * 100

# Step 2: Filter columns with more than 20% missing values
high_missing_columns = percent_missing[percent_missing > 20]

# Step 3: Sort the columns by percentage of missing values (highest to lowest)
high_missing_columns = high_missing_columns.sort_values(ascending=False)

# Step 4: Plot the results as a bar chart
ax = high_missing_columns.plot.bar(
    title='Percentage of Missing Values in Columns',  # Title of the chart
    figsize=(12, 5)  # Size of the chart
)

# Step 5: Add a label for the y-axis
ax.set_ylabel('% of Missing Values')
# Out:
# Text(0, 0.5, '% of Missing Values')

# %%
missing_percentage = (IPED_data.isnull().sum() / len(IPED_data)) * 100
print(missing_percentage)
# Out:
# ID number                                                 0.000000
# Name                                                      0.000000
# year                                                      0.000000
# ZIP code                                                  0.000000
# Highest degree offered                                    0.000000
#                                                            ...
# Percent of freshmen receiving student loan aid            2.737940
# Percent of freshmen receiving federal student loans       2.737940
# Percent of freshmen receiving other loan aid              2.737940
# Endowment assets (year end) per FTE enrollment (GASB)    66.362451
# Endowment assets (year end) per FTE enrollment (FASB)    37.418514
# Length: 145, dtype: float64

# %%
missing_percentage = missing_percentage.sort_values(ascending=False)
print(missing_percentage)
# Out:
# Endowment assets (year end) per FTE enrollment (GASB)      66.362451
# SAT Writing 25th percentile score                          53.455020
# SAT Writing 75th percentile score                          53.455020
# Number of first-time undergraduates - foreign countries    40.612777
# Percent of first-time undergraduates - out-of-state        40.612777
#                                                              ...
# Level of institution                                        0.000000
# Control of institution                                      0.000000
# Historically Black College or University                    0.000000
# Tribal college                                              0.000000
# State abbreviation                                          0.000000
# Length: 145, dtype: float64

# %%
threshold = 0.2  # 20% missing values

# Calculate the percentage of missing values for each column
missing_percentage = IPED_data.isnull().mean()
missing_percentage
# Out:
# ID number                                                0.000000
# Name                                                     0.000000
# year                                                     0.000000
# ZIP code                                                 0.000000
# Highest degree offered                                   0.000000
#                                                            ...
# Percent of freshmen receiving student loan aid           0.027379
# Percent of freshmen receiving federal student loans      0.027379
# Percent of freshmen receiving other loan aid             0.027379
# Endowment assets (year end) per FTE enrollment (GASB)    0.663625
# Endowment assets (year end) per FTE enrollment (FASB)    0.374185
# Length: 145, dtype: float64

# %%
# Identify columns with more than the threshold percentage of missing values
columns_to_drop = missing_percentage[missing_percentage > threshold].index

# %%
columns_to_drop
# Out:
# Index(['SAT Critical Reading 25th percentile score',
#        'SAT Critical Reading 75th percentile score',
#        'SAT Math 25th percentile score', 'SAT Math 75th percentile score',
#        'SAT Writing 25th percentile score',
#        'SAT Writing 75th percentile score',
#        'ACT Composite 25th percentile score',
#        'ACT Composite 75th percentile score',
#        'Number of first-time undergraduates - in-state',
#        'Percent of first-time undergraduates - in-state',
#        'Number of first-time undergraduates - out-of-state',
#        'Percent of first-time undergraduates - out-of-state',
#        'Number of first-time undergraduates - foreign countries',
#        'Percent of first-time undergraduates - foreign countries',
#        'Number of first-time undergraduates - residence unknown',
#        'Percent of first-time undergraduates - residence unknown',
#        'Endowment assets (year end) per FTE enrollment (GASB)',
# ...

# %%
# Drop the identified columns
df_cleaned = IPED_data.drop(columns=columns_to_drop)

# %%
df_cleaned.head()
# Out:
#    ID number                                 Name  year    ZIP code  \
# 0     100654             Alabama A & M University  2013       35762
# 1     100663  University of Alabama at Birmingham  2013  35294-0110
# 2     100690                   Amridge University  2013  36117-3553
# 3     100706  University of Alabama in Huntsville  2013       35899
# 4     100724             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# ...

# %%
imp_cols=['Name', 'year', 'Highest degree offered', "Offers Bachelor's degree",
       "Offers Master's degree",
       "Offers Doctor's degree - research/scholarship",
       "Offers Doctor's degree - professional practice", 'Applicants total',
       'Admissions total', 'Enrolled total', 'Estimated enrollment, total',
       'Tuition and fees, 2013-14',
       'Total price for in-state students living on campus 2013-14',
       'Total price for out-of-state students living on campus 2013-14',
       'State abbreviation', 'Control of institution', 'Total  enrollment',
       'Full-time enrollment', 'Part-time enrollment',
       'Undergraduate enrollment', 'Graduate enrollment',
       'Full-time undergraduate enrollment',
       'Part-time undergraduate enrollment',
       'Percent of total enrollment that are women',
       'Percent of undergraduate enrollment that are women',
       'Percent of graduate enrollment that are women',
       'Graduation rate - Bachelor degree within 4 years, total',
       'Graduation rate - Bachelor degree within 5 years, total',
       'Graduation rate - Bachelor degree within 6 years, total',
       ]
df_IPED = df_cleaned[imp_cols]

# %%
df_IPED.head()
# Out:
#                                   Name  year  \
# 0             Alabama A & M University  2013
# 1  University of Alabama at Birmingham  2013
# 2                   Amridge University  2013
# 3  University of Alabama in Huntsville  2013
# 4             Alabama State University  2013
#
#                               Highest degree offered Offers Bachelor's degree  \
# 0             Doctor's degree - research/scholarship                      Yes
# 1  Doctor's degree - research/scholarship and pro...                      Yes
# 2  Doctor's degree - research/scholarship and pro...                      Yes
# 3  Doctor's degree - research/scholarship and pro...                      Yes
# 4  Doctor's degree - research/scholarship and pro...                      Yes
#
#   Offers Master's degree Offers Doctor's degree - research/scholarship  \
# 0                    Yes                                           Yes
# 1                    Yes                                           Yes
# ...

# %%
df_IPED.shape
# Out:
# (1534, 29)

# %%
df_IPED.isna().sum()
# Out:
# Name                                                                0
# year                                                                0
# Highest degree offered                                              0
# Offers Bachelor's degree                                            2
# Offers Master's degree                                              2
# Offers Doctor's degree - research/scholarship                       2
# Offers Doctor's degree - professional practice                      2
# Applicants total                                                  157
# Admissions total                                                  157
# Enrolled total                                                    157
# Estimated enrollment, total                                         2
# Tuition and fees, 2013-14                                          37
# Total price for in-state students living on campus 2013-14        134
# ...

# %%
df_IPED[df_IPED['Total  enrollment'].isna()]
# Out:
#                                   Name  year  \
# 257        University of North Georgia  2013
# 1308  Texas A & M University-Galveston  2013
#
#                         Highest degree offered Offers Bachelor's degree  \
# 257   Doctor's degree -  professional practice                      NaN
# 1308    Doctor's degree - research/scholarship                      NaN
#
#      Offers Master's degree Offers Doctor's degree - research/scholarship  \
# 257                     NaN                                           NaN
# 1308                    NaN                                           NaN
#
#      Offers Doctor's degree - professional practice  Applicants total  \
# 257                                             NaN               NaN
# 1308                                            NaN               NaN
#
#       Admissions total  Enrolled total  ...  Undergraduate enrollment  \
# 257                NaN             NaN  ...                       NaN
# ...

# %%
df_IPED_cleaned = df_IPED.dropna()

# %%
df_IPED_cleaned
# Out:
#                                              Name  year  \
# 0                        Alabama A & M University  2013
# 1             University of Alabama at Birmingham  2013
# 3             University of Alabama in Huntsville  2013
# 4                        Alabama State University  2013
# 5                       The University of Alabama  2013
# ...                                           ...   ...
# 1503                Florida Gulf Coast University  2013
# 1507            Johnson & Wales University-Denver  2013
# 1511  California State University-Channel Islands  2013
# 1516                         Ave Maria University  2013
# 1525    University of South Florida-St Petersburg  2013
#
#                                  Highest degree offered  \
# 0                Doctor's degree - research/scholarship
# 1     Doctor's degree - research/scholarship and pro...
# 3     Doctor's degree - research/scholarship and pro...
# 4     Doctor's degree - research/scholarship and pro...
# ...

# %%
df_IPED_cleaned.isna().sum()
# Out:
# Name                                                              0
# year                                                              0
# Highest degree offered                                            0
# Offers Bachelor's degree                                          0
# Offers Master's degree                                            0
# Offers Doctor's degree - research/scholarship                     0
# Offers Doctor's degree - professional practice                    0
# Applicants total                                                  0
# Admissions total                                                  0
# Enrolled total                                                    0
# Estimated enrollment, total                                       0
# Tuition and fees, 2013-14                                         0
# Total price for in-state students living on campus 2013-14        0
# Total price for out-of-state students living on campus 2013-14    0
# ...

# %%
df_IPED_cleaned.describe()
# Out:
#          year  Applicants total  Admissions total  Enrolled total  \
# count  1116.0       1116.000000       1116.000000     1116.000000
# mean   2013.0       7280.008065       4050.931900     1192.931900
# std       0.0       9479.188312       4602.472198     1370.377736
# min    2013.0          4.000000          4.000000        2.000000
# 25%    2013.0       1705.500000       1110.750000      338.750000
# 50%    2013.0       3720.000000       2345.000000      639.500000
# 75%    2013.0       8597.000000       4931.000000     1449.500000
# max    2013.0      72676.000000      35815.000000    10241.000000
#
#        Estimated enrollment, total  Tuition and fees, 2013-14  \
# count                  1116.000000                1116.000000
# mean                   8554.193548               21170.265233
# std                   10114.608152               12282.931254
# min                     219.000000                4358.000000
# ...

# %%
total_zero = df_IPED_cleaned[df_IPED_cleaned.loc[:]==0].count().sum()
total_zero
# Out:
# 7

# %%
df_IPED_cleaned[df_IPED_cleaned['Total  enrollment'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, year, Highest degree offered, Offers Bachelor's degree, Offers Master's degree, Offers Doctor's degree - research/scholarship, Offers Doctor's degree - professional practice, Applicants total, Admissions total, Enrolled total, Estimated enrollment, total, Tuition and fees, 2013-14, Total price for in-state students living on campus 2013-14, Total price for out-of-state students living on campus 2013-14, State abbreviation, Control of institution, Total  enrollment, Full-time enrollment, Part-time enrollment, Undergraduate enrollment, Graduate enrollment, Full-time undergraduate enrollment, Part-time undergraduate enrollment, Percent of total enrollment that are women, Percent of undergraduate enrollment that are women, Percent of graduate enrollment that are women, Graduation rate - Bachelor degree within 4 years, total, Graduation rate - Bachelor degree within 5 years, total, Graduation rate - Bachelor degree within 6 years, total]
# Index: []
#
# ...

# %%
high_app = df_IPED_cleaned.nlargest(20, 'Applicants total')[['Name', 'Applicants total']]

# %%
high_app
# Out:
#                                            Name  Applicants total
# 84         University of California-Los Angeles           72676.0
# 81            University of California-Berkeley           61717.0
# 86           University of California-San Diego           60832.0
# 841                         New York University           57845.0
# 83              University of California-Irvine           56515.0
# 87       University of California-Santa Barbara           55258.0
# 77       California State University-Long Beach           55019.0
# 863               St John's University-New York           51634.0
# 126                  San Diego State University           51163.0
# 82               University of California-Davis           49820.0
# 1371                         Liberty University           48054.0
# 1133  Pennsylvania State University-Main Campus           47552.0
# 559                     Northeastern University           47364.0
# ...

# %%
total_zero = df_IPED_cleaned[df_IPED_cleaned.loc[:]==0].count().sum()
total_zero
# Out:
# 7

# %%
# Step 1: Replace 0 with NaN in the DataFrame
df_IPED_cleaned.replace(0, np.nan, inplace=True)

# Step 2: Check if any 0 values remain
total_zero = (df_IPED_cleaned == 0).sum().sum()
print("Total remaining 0 values:", total_zero)
# Out:
# Total remaining 0 values: 0

# %%
# Row with the highest applicants_total
highest_applicant = df_IPED_cleaned.nlargest(1, 'Applicants total')[['Name', 'Applicants total']]
highest_applicant
# Out:
#                                     Name  Applicants total
# 84  University of California-Los Angeles           72676.0

# %%
# Row with the lowest applicants_total
lowest_applicant = df_IPED_cleaned.nsmallest(1, 'Applicants total')[['Name', 'Applicants total']]
lowest_applicant
# Out:
#                  Name  Applicants total
# 1343  Goddard College               4.0

# %%
df_IPED_cleaned
# Out:
#                                              Name  year  \
# 0                        Alabama A & M University  2013
# 1             University of Alabama at Birmingham  2013
# 3             University of Alabama in Huntsville  2013
# 4                        Alabama State University  2013
# 5                       The University of Alabama  2013
# ...                                           ...   ...
# 1503                Florida Gulf Coast University  2013
# 1507            Johnson & Wales University-Denver  2013
# 1511  California State University-Channel Islands  2013
# 1516                         Ave Maria University  2013
# 1525    University of South Florida-St Petersburg  2013
#
#                                  Highest degree offered  \
# 0                Doctor's degree - research/scholarship
# 1     Doctor's degree - research/scholarship and pro...
# 3     Doctor's degree - research/scholarship and pro...
# 4     Doctor's degree - research/scholarship and pro...
# ...

# %%
df_IPED_cleaned.to_csv('IPED_cleaned_data.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'high_app' is your DataFrame containing the top 20 universities
plt.figure(figsize=(12, 8))
sns.barplot(x='Applicants total', y='Name', data=high_app)
plt.title('Top 20 American Universities with the Most Applications in 2013')
plt.xlabel('Number of Applications')
plt.ylabel('University Name')
plt.tight_layout()
plt.show()

# %%
df_IPED_cleaned.columns
# Out:
# Index(['Name', 'year', 'Highest degree offered', 'Offers Bachelor's degree',
#        'Offers Master's degree',
#        'Offers Doctor's degree - research/scholarship',
#        'Offers Doctor's degree - professional practice', 'Applicants total',
#        'Admissions total', 'Enrolled total', 'Estimated enrollment, total',
#        'Tuition and fees, 2013-14',
#        'Total price for in-state students living on campus 2013-14',
#        'Total price for out-of-state students living on campus 2013-14',
#        'State abbreviation', 'Control of institution', 'Total  enrollment',
#        'Full-time enrollment', 'Part-time enrollment',
#        'Undergraduate enrollment', 'Graduate enrollment',
#        'Full-time undergraduate enrollment',
#        'Part-time undergraduate enrollment',
#        'Percent of total enrollment that are women',
#        'Percent of undergraduate enrollment that are women',
#        'Percent of graduate enrollment that are women',
# ...

# %%
# Replacing extra spaces and special characters, ensuring only one underscore
df_IPED_cleaned.columns = (
    df_IPED_cleaned.columns
    .str.replace(r'\s+|\/|\s-\s|-', '_', regex=True)  # Replace spaces, '/', ' - ', and '-' with '_'
    .str.replace(r'_+', '_', regex=True)  # Replace multiple underscores with a single underscore
    .str.lower()  # Convert to lowercase
    .str.replace(r"[\',-]", "", regex=True)  # Remove special characters like commas, apostrophes, and hyphens
)

# %%
df_IPED_cleaned.columns
# Out:
# Index(['name', 'year', 'highest_degree_offered', 'offers_bachelors_degree',
#        'offers_masters_degree', 'offers_doctors_degree_research_scholarship',
#        'offers_doctors_degree_professional_practice', 'applicants_total',
#        'admissions_total', 'enrolled_total', 'estimated_enrollment_total',
#        'tuition_and_fees_2013_14',
#        'total_price_for_in_state_students_living_on_campus_2013_14',
#        'total_price_for_out_of_state_students_living_on_campus_2013_14',
#        'state_abbreviation', 'control_of_institution', 'total_enrollment',
#        'full_time_enrollment', 'part_time_enrollment',
#        'undergraduate_enrollment', 'graduate_enrollment',
#        'full_time_undergraduate_enrollment',
#        'part_time_undergraduate_enrollment',
#        'percent_of_total_enrollment_that_are_women',
#        'percent_of_undergraduate_enrollment_that_are_women',
#        'percent_of_graduate_enrollment_that_are_women',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plots
sns.set(style="whitegrid")

# Define the columns and their corresponding titles
columns = ['applicants_total', 'admissions_total', 'enrolled_total']
titles = [
    "Histogram of Number of Applications",
    "Histogram of Number of Admissions",
    "Histogram of Number of Enrollments"
]

# Create a figure with a specific size
plt.figure(figsize=(16, 6))

# Loop through the columns and titles
for i, (col, title) in enumerate(zip(columns, titles), 1):
    plt.subplot(1, 3, i)
    sns.histplot(df_IPED_cleaned[col], bins=50, kde=True, color='skyblue')
    plt.title(f"{title}\nMean: {df_IPED_cleaned[col].mean():.1f}, Median: {df_IPED_cleaned[col].median():.1f}")
    plt.xlabel(f'Number of {col.replace("_total", "").replace("_", " ").capitalize()}')
    plt.ylabel('Frequency')
    plt.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout(pad=2)
plt.show()

# %%
# Create a figure with a specific size
plt.figure(figsize=(16, 6))

# First subplot: Applications vs Admissions
plt.subplot(1, 2, 1)
plt.title('APPLICATIONS VS ADMISSIONS')
sns.scatterplot(
    y=df_IPED_cleaned['admissions_total'], 
    x=df_IPED_cleaned['applicants_total'], 
    hue=df_IPED_cleaned['control_of_institution']
)
plt.ylabel('Number of Admissions')
plt.xlabel('Number of Applications')
plt.grid()

# Second subplot: Admissions vs Enrollments
plt.subplot(1, 2, 2)
plt.title('ADMISSIONS VS ENROLLMENTS')
sns.scatterplot(
    x='admissions_total', 
    y='enrolled_total', 
    data=df_IPED_cleaned, 
    hue='control_of_institution'
)
plt.ylabel('Number of Enrollments')
plt.xlabel('Number of Admissions')
plt.grid()

# Adjust layout to prevent overlap
plt.tight_layout(pad=2)
plt.show()

# %%
# Calculate enrollment rate as a percentage and round to 2 decimal places
df_IPED_cleaned['enrollment_rate'] = (
    (df_IPED_cleaned['enrolled_total'] / df_IPED_cleaned['admissions_total']) * 100
).round(2)

df_IPED_cleaned.head(2)
# Out:
#                                   name  year  \
# 0             Alabama A & M University  2013
# 1  University of Alabama at Birmingham  2013
#
#                               highest_degree_offered offers_bachelors_degree  \
# 0             Doctor's degree - research/scholarship                     Yes
# 1  Doctor's degree - research/scholarship and pro...                     Yes
#
#   offers_masters_degree offers_doctors_degree_research_scholarship  \
# 0                   Yes                                        Yes
# 1                   Yes                                        Yes
#
#   offers_doctors_degree_professional_practice  applicants_total  \
# 0                                  Implied no            6142.0
# 1                                         Yes            5689.0
#
#    admissions_total  enrolled_total  ...  graduate_enrollment  \
# 0            5521.0          1104.0  ...                969.0
# 1            4934.0          1773.0  ...               7066.0
#
# ...

# %%
# Calculate acceptance rate as a percentage and round to 2 decimal places
df_IPED_cleaned['acceptance_rate'] = (
    (df_IPED_cleaned['admissions_total'] / df_IPED_cleaned['applicants_total']) * 100
).round(2)

# %%
df_IPED_cleaned.head()
# Out:
#                                   name  year  \
# 0             Alabama A & M University  2013
# 1  University of Alabama at Birmingham  2013
# 3  University of Alabama in Huntsville  2013
# 4             Alabama State University  2013
# 5            The University of Alabama  2013
#
#                               highest_degree_offered offers_bachelors_degree  \
# 0             Doctor's degree - research/scholarship                     Yes
# 1  Doctor's degree - research/scholarship and pro...                     Yes
# 3  Doctor's degree - research/scholarship and pro...                     Yes
# 4  Doctor's degree - research/scholarship and pro...                     Yes
# 5  Doctor's degree - research/scholarship and pro...                     Yes
#
#   offers_masters_degree offers_doctors_degree_research_scholarship  \
# 0                   Yes                                        Yes
# 1                   Yes                                        Yes
# ...

# %%
# Set the figure size
plt.figure(figsize=(12, 5))

# Create the scatter plot
sns.scatterplot(
    x='applicants_total', 
    y='enrollment_rate', 
    data=df_IPED_cleaned,  # Ensure you're using the correct DataFrame
    hue='control_of_institution',  # Optional: Add color based on institution type
    palette='viridis',  # Optional: Use a nice color palette
    alpha=0.7  # Optional: Add transparency to points
)

# Add title and labels
plt.title('APPLICATIONS VS ENROLLMENT RATE', fontsize=16)
plt.ylabel('Enrollment Rate %', fontsize=12)
plt.xlabel('Number of Applications', fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(16, 6))

# Create the scatter plot
sns.scatterplot(
    x='acceptance_rate', 
    y='enrollment_rate', 
    data=df_IPED_cleaned,  # Ensure you're using the correct DataFrame
    hue='control_of_institution',  # Color points by institution type
    palette='viridis',  # Use a visually appealing color palette
    alpha=0.7,  # Add transparency to points
    s=100  # Adjust point size for better visibility
)

# Add title and labels
plt.title('ACCEPTANCE VS ENROLLMENT RATES', fontsize=16, pad=20)
plt.ylabel('Enrollment Rate %', fontsize=12)
plt.xlabel('Acceptance Rate %', fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add a legend with a title
plt.legend(title='Control of Institution', title_fontsize=12, fontsize=10)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter out rows with null acceptance rates and select relevant columns
high_accept = (
    df_IPED_cleaned[df_IPED_cleaned['acceptance_rate'].notnull()]
    [['name', 'acceptance_rate', 'enrollment_rate']]
    .sort_values('acceptance_rate', ascending=False)  # Sort by acceptance rate in descending order
    .head(20)  # Select top 10
)

low_accept = (
    df_IPED_cleaned[df_IPED_cleaned['acceptance_rate'].notnull()]
    [['name', 'acceptance_rate', 'enrollment_rate']]
    .sort_values('acceptance_rate', ascending=True)  # Sort by acceptance rate in ascending order
    .head(20)  # Select top 10
)

# %%
high_accept
# Out:
#                                     name  acceptance_rate  enrollment_rate
# 709    Montana State University-Northern           100.00            53.19
# 1343                     Goddard College           100.00            50.00
# 451              University of Pikeville           100.00            21.40
# 1313  The University of Texas at El Paso            99.81            48.70
# 799        College of Staten Island CUNY            99.75            26.19
# 15            University of West Alabama            99.57            82.61
# 1346                Lyndon State College            99.34            27.14
# 421             Ottawa University-Ottawa            98.88            54.92
# 1325          Wayland Baptist University            98.62            60.73
# 1023             East Central University            98.14            64.42
# 146        Colorado Christian University            97.64            38.60
# ...

# %%
# Set the figure size
plt.figure(figsize=(20, 9))

# First subplot: Top 25 universities with highest acceptance rates
plt.subplot(1, 2, 1)
ind = np.arange(len(high_accept))  # Number of universities
width = 0.35  # Width of bars

# Plot acceptance rate and enrollment rate bars with new colors
plt.bar(ind, high_accept.acceptance_rate, width, label='Acceptance Rate', color='#1f77b4')  # Blue
plt.bar(ind + width, high_accept.enrollment_rate, width, label='Enrollment Rate', color='#ff7f0e')  # Orange

# Add title, labels, and legend
plt.title('Acceptance and Enrollment Rates\n25 Universities With the Highest Acceptance Rate', fontsize=20)
plt.ylabel('Rates %', fontsize=20)
plt.xticks(ind + width, high_accept.name.values, rotation=90, fontsize=20)
plt.legend(loc='best')

# Second subplot: Top 25 universities with lowest acceptance rates
plt.subplot(1, 2, 2)
ind = np.arange(len(low_accept))  # Number of universities
width = 0.35  # Width of bars

# Plot acceptance rate and enrollment rate bars with new colors
plt.bar(ind, low_accept.acceptance_rate, width, label='Acceptance Rate', color='#1f77b4')  # Blue
plt.bar(ind + width, low_accept.enrollment_rate, width, label='Enrollment Rate', color='#ff7f0e')  # Orange

# Add title, labels, and legend
plt.title('Acceptance and Enrollment Rates\n25 Universities With the Lowest Acceptance Rate', fontsize=20)
plt.ylabel('Rates %', fontsize=20)
plt.xticks(ind + width, low_accept.name.values, rotation=90, fontsize=15)
plt.legend(loc='best')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a joint plot
g = sns.jointplot(
    x='enrollment_rate', 
    y='applicants_total', 
    data=df_IPED_cleaned,  # Ensure you're using the correct DataFrame
    hue='control_of_institution',  # Color points by institution type
    palette='viridis',  # Use a visually appealing color palette
    height=6,  # Set the height of the plot
    alpha=0.7,  # Add transparency to points
    s=50  # Adjust point size
)

# Set axis labels
g.set_axis_labels("Enrollment Rate %", "Number of Applications", fontsize=12)

# Add a title
plt.suptitle("Enrollment Rate vs Number of Applications", y=1.02, fontsize=14)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a joint plot
g = sns.jointplot(
    x='tuition_and_fees_2013_14', 
    y='enrollment_rate', 
    data=df_IPED_cleaned,  # Ensure you're using the correct DataFrame
    hue='control_of_institution',  # Color points by institution type
    palette='viridis',  # Use a visually appealing color palette
    height=9,  # Set the height of the plot
    alpha=0.7,  # Add transparency to points
    s=50  # Adjust point size
)

# Set axis labels
g.set_axis_labels('Tuition and Fees ($)', 'Enrollment Rate %', fontsize=12)

# Add a title
plt.suptitle("Tuition and Fees (2013-14) vs Enrollment Rate", y=1.02, fontsize=14)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_IPED_cleaned.to_csv('IPED_cleaned_data_1.csv', index=False)
